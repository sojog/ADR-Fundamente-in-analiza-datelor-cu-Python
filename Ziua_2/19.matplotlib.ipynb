# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [10]
y = [10]

plt.scatter(x, y)

# %%
x = [7]
y = [8]

plt.scatter(x, y)

# %%
x = [7, 11]
y = [8, 10]

plt.scatter(x, y)

# %%
x = [7, 11, 15]
y = [8, 10, 15]

plt.scatter(x, y)

# %%
x = [7, 11, 15]
y = [8, 10, 15]

plt.scatter(x, y)
plt.plot(x, y)

# %%
x = [7, 20, 11, 15]
y = [8, 20, 10, 15]

plt.scatter(x, y)
plt.plot(x, y)

# %%
x = [7, 11, 15,  20]
y = [8, 10, 15, 20]

plt.scatter(x, y)
plt.plot(x, y)

# %%
x = [7, 11, 15,  20]
y = [7, 11, 15, 20]

plt.scatter(x, y)
plt.plot(x, y)

# %%
x = [7, 11, 15,  20]
y = [7, 10, 16, 20]

plt.scatter(x, y)
plt.plot(x, y)

# %%
x = [7, 11, 15,  20]
y = [7, 10, 16, 20]

plt.scatter(x, y)

y_liniar = x

plt.plot(x, y_liniar)

# %%
x = [7, 11, 15,  20]
y = [7, 10, 16, 20]

plt.scatter(x, y)


def f(x):
    return x

y_liniar = x

plt.plot(x, y_liniar)
